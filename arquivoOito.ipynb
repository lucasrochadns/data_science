# %%
import numpy as np

# %%
a = np.array([1, 2, 3])
b = np.array([[1, 2], [3, 4]])

# %%
a
# Out:
# array([1, 2, 3])

# %%
b
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
b.shape
# Out:
# (2, 2)

# %%
b.ndim
# Out:
# 2

# %%
a.size
# Out:
# 3
