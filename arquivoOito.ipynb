# %%
import numpy as np

# %%
a = np.array([1, 2, 3])
b = np.array([[1, 2], [3, 4]])

# %%
a
# Out:
# array([1, 2, 3])

# %%
b
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
b.shape
# Out:
# (2, 2)

# %%
b.ndim
# Out:
# 2

# %%
a.size
# Out:
# 3

# %%
a.dtype
# Out:
# dtype('int64')

# %%
a[0]
# Out:
# np.int64(1)

# %%
#todas as linhas da coluna 1
b[:,1]
# Out:
# array([2, 4])
