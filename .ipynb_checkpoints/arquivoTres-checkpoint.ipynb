# %%
import pandas as pd

# %%
df = pd.read_csv('house.csv')

# %%
filterOne = df.loc[(df['Rooms'] == 3) & (df['Type'] == 'h')]

# %%
filterOne
# Out:
#              Suburb           Address  Rooms Type      Price Method  \
# 574       St Albans    210 William St      1    h  1100000.0     SP
# 1471      Northcote      25 Albert St      1    h        NaN     PI
# 1625   Airport West       8 Moorna Dr      1    h   680000.0     VB
# 2293        Emerald  80 Kilvington Dr      1    h   462000.0      S
# 2340        Newport    3/3 Jubilee St      1    h   340000.0     SP
# ...             ...               ...    ...  ...        ...    ...
# 60796       Windsor       108 Peel St      1    h   900000.0     VB
# 61181        Plenty         2 Hawk Vw      1    h   942000.0      S
# 61425   Craigieburn  19 Prominence Ri      1    h   475000.0      S
# 61739   Albert Park       9 Durham St      1    h   985000.0      S
# 62199    Yarraville   10 Gladstone St      1    h        NaN      S
#
#              SellerG        Date  Postcode             Regionname  \
# 574              Ray   1/04/2017      3021   Western Metropolitan
# ...
